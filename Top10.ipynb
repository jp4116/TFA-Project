# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("311_Service_Requests_2020.csv")
df.head()
# Out:
# C:\Users\YFonseca23\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1    45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2    45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3    45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4    45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning  3 or More
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# ...

# %%
df_ = df[df['Incident Zip'] == 10027]
df_
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 305        45278190  01/01/2020 01:10:07 AM  01/01/2020 09:00:02 AM   NYPD
# 542        45281550  01/01/2020 01:52:36 AM  01/01/2020 02:58:35 AM   NYPD
# 553        45281044  01/01/2020 01:54:22 AM  01/01/2020 11:12:27 AM   NYPD
# 614        45289780  01/01/2020 02:04:07 AM  01/01/2020 05:06:45 AM   NYPD
# 693        45287804  01/01/2020 02:18:51 AM  01/01/2020 05:07:33 AM   NYPD
# ...             ...                     ...                     ...    ...
# 2586194    48534154  12/30/2020 07:59:11 PM  01/05/2021 02:19:26 PM    DOT
# 2586950    48535401  12/30/2020 10:43:45 PM  12/30/2020 10:52:58 PM   NYPD
# 2587055    48529353  12/30/2020 11:03:00 PM  12/31/2020 11:08:00 AM    DEP
# 2587073    48533848  12/30/2020 11:09:26 PM  12/31/2020 12:51:56 AM   NYPD
# 2587183    48527925  12/30/2020 11:33:43 PM  12/31/2020 12:34:30 AM   NYPD
#
# ...

# %%
cause = df_.Descriptor
cause
# Out:
# 305                            Loud Music/Party
# 542                            Loud Music/Party
# 553                            Loud Music/Party
# 614                            Loud Music/Party
# 693                            Loud Music/Party
#                            ...
# 2586194                         Broken Sidewalk
# 2586950                        Loud Music/Party
# 2587055    Lead Kit Request (Residential) (L10)
# 2587073                            Loud Talking
# 2587183                        Loud Music/Party
# Name: Descriptor, Length: 21470, dtype: object

# %%
top10 = cause.value_counts()[:10]
top10
# Out:
# Loud Music/Party                 4661
# Banging/Pounding                 1618
# ENTIRE BUILDING                  1346
# APARTMENT ONLY                    792
# Social Distancing                 703
# Loud Talking                      700
# Car/Truck Music                   539
# Posted Parking Sign Violation     404
# PESTS                             345
# Business not in compliance        343
# Name: Descriptor, dtype: int64

# %% [markdown]
# <blockquote>
#     Some tests

# %%
type(top10)
# Out:
# pandas.core.series.Series

# %%
x= cause.value_counts().head(10)
x
# Out:
# Loud Music/Party                 4661
# Banging/Pounding                 1618
# ENTIRE BUILDING                  1346
# APARTMENT ONLY                    792
# Social Distancing                 703
# Loud Talking                      700
# Car/Truck Music                   539
# Posted Parking Sign Violation     404
# PESTS                             345
# Business not in compliance        343
# Name: Descriptor, dtype: int64

# %%
x == top10
# Out:
# Loud Music/Party                 True
# Banging/Pounding                 True
# ENTIRE BUILDING                  True
# APARTMENT ONLY                   True
# Social Distancing                True
# Loud Talking                     True
# Car/Truck Music                  True
# Posted Parking Sign Violation    True
# PESTS                            True
# Business not in compliance       True
# Name: Descriptor, dtype: bool

# %%
print(df_['Created Date'])
# Out:
# 305        01/01/2020 01:10:07 AM
# 542        01/01/2020 01:52:36 AM
# 553        01/01/2020 01:54:22 AM
# 614        01/01/2020 02:04:07 AM
# 693        01/01/2020 02:18:51 AM
#                     ...
# 2586194    12/30/2020 07:59:11 PM
# 2586950    12/30/2020 10:43:45 PM
# 2587055    12/30/2020 11:03:00 PM
# 2587073    12/30/2020 11:09:26 PM
# 2587183    12/30/2020 11:33:43 PM
# Name: Created Date, Length: 21470, dtype: object
